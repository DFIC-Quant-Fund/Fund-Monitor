# %%
import yaml

with open("../config.yaml", "r") as f:
    config = yaml.safe_load(f)

print(config['starting_cash'])
print(config['asset_allocation']['equities'])
print(config['portfolios'][0]['name'])
# Out:
# 101644.99
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 7
#       4     config = yaml.safe_load(f)
#       6 print(config['starting_cash'])
# ----> 7 print(config['asset_allocation']['equities'])
#       8 print(config['portfolios'][0]['name'])
#
# KeyError: 'asset_allocation'

# %%
from flask import Flask, jsonify
import json
import yaml
with open("../portfolios/dfic_core.yaml", "r") as f:
    config = yaml.safe_load(f)

funds = config['funds']
print(funds)
print(json.dumps({"success": True, "data": funds}, indent=4))
# Out:
# [{'name': 'Macro Fund', 'thesis': 'We are a very good fund, make lots of money, and are very good at it.'}, {'name': 'Industrials Fund', 'thesis': 'We are a very good fund, make lots of money, and are very good at it.'}, {'name': 'Resources Fund', 'thesis': 'We seek to invest in high-quality resource companies with strong fundamentals that are trading at a discount to intrinsic value. Our focus is on long-term value creation through disciplined capital allocation in undervalued sectors of the natural resources sector.'}, {'name': 'C&H Fund', 'thesis': 'We are a very good fund, make lots of money, and are very good at it.'}, {'name': 'TMT Fund', 'thesis': 'We are a very good fund, make lots of money, and are very good at it.'}, {'name': 'Financials Fund', 'thesis': 'We are a very good fund, make lots of money, and are very good at it.'}]
# {
#     "success": true,
#     "data": [
#         {
#             "name": "Macro Fund",
#             "thesis": "We are a very good fund, make lots of money, and are very good at it."
#         },
#         {
#             "name": "Industrials Fund",
#             "thesis": "We are a very good fund, make lots of money, and are very good at it."
#         },
#         {
#             "name": "Resources Fund",
#             "thesis": "We seek to invest in high-quality resource companies with strong fundamentals that are trading at a discount to intrinsic value. Our focus is on long-term value creation through disciplined capital allocation in undervalued sectors of the natural resources sector."
#         },
#         {
#             "name": "C&H Fund",
#             "thesis": "We are a very good fund, make lots of money, and are very good at it."
#         },
#         {
#             "name": "TMT Fund",
#             "thesis": "We are a very good fund, make lots of money, and are very good at it."
#         },
#         {
#             "name": "Financials Fund",
#             "thesis": "We are a very good fund, make lots of money, and are very good at it."
#         }
#     ]
# }
